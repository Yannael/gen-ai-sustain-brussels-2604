# %% [markdown]
# [Course material - Sustain.Brussels - "Avdanced AI workflows with LLM" - 20/04/2026 - 22/04/2026](https://github.com/Yannael/gen-ai-sustain-brussels-2604).
#
# # Google Colab
#
# ## Subtitle
#
# [Google Colab](https://www.youtube.com/watch?v=inN8seMm7UI) is a service provided by Google Research and requires to have a Google account. It allows to run Python notebooks for free on Google cloud.
#
# The computational resources provided by Google Colab can fluctuate. They depend on available Google resources, as well as your usage of the service (intense use may lead to lower resources). You may however expect to have one core, and a few gigabytes of RAM. Google Colab also provides a free GPU, whose model may vary depending on available resources. Provided GPU models often include Nvidia K80s, T4s, P4s, or P100s. See this link for more details on the resources that Google can provide.
#
# ### Markdown
#
# - Point 1
# - Point 2

# %% [markdown]
# ## Test it!

# %%
print("Hello world here we are !")
# Out:
# Hello world here we are !

# %% [markdown]
# You can also use 'Shift+ENTER' to execute a cell

# %%
2+2
# Out:
# 4

# %%
# !pip install openai

# %%
from openai import OpenAI
client = OpenAI(api_key="...")

completion = client.chat.completions.create(
  model="gpt-5.4",
  messages=[
    {"role": "system", "content": "You are a poetic assistant, skilled in explaining complex programming concepts with creative flair."},
    {"role": "user", "content": "Compose a poem that explains the concept of recursion in programming."}
  ]
)

# %%
print(completion.choices[0].message.content)
# Out:
# A function stood before a door
# And asked, “What came before?”
# The hallway bent, the room grew small,
# It called itself to learn it all.
#
# “To solve this task,” it softly said,
# “I’ll solve a smaller one instead.
# And when that tiny knot is through,
# Its answer helps me finish too.”
#
# So down it stepped through nested light,
# Each mirror framing less of night,
# Until it reached a simple place,
# A quiet, undisputed base.
#
# “No further now,” the function knew,
# “This smallest case is plainly true.”
# From there it climbed, step after step,
# With every prior promise kept.
#
# A factorial, a branching tree,
# A search through depth, a melody
# Where patterns echo in the code
# And smaller paths share one same road.
#
# But heed the spell: without an end,
# The self-call is no faithful friend.
# For endless descent, stack piled high,
# Will overflow and crash the sky.
#
# Recursion, then, is artful seeing:
# A whole contained in lesser being.
# ...
